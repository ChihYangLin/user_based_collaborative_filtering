# %% [markdown]
# ## 載入模組

# %%
import pandas as pd
import numpy as np
from sklearn.metrics.pairwise import cosine_similarity

# %% [markdown]
# ## 載入資料

# %%
df = pd.read_csv("retail_data_09282020.csv",encoding="utf-8")
df.head()
# Out:
#    CustomerID  InvoiceNo InvoiceDate InvoiceTime StockCode  \
# 0       16446     581483  2011-12-09    09:15:00     23843
# 1       12346     541431  2011-01-18    10:01:00     23166
# 2       12901     573008  2011-10-27    12:26:00     84077
# 3       13135     554868  2011-05-27    10:52:00     22197
# 4       18087     544612  2011-02-22    10:43:00     22053
#
#                 ProductName  Quantity  UnitPrice  Subtotal  \
# 0          中興米外銷日本之米(圓ㄧ)3Kg       285        169     48165
# 1   樂米穀場花東自然農耕特哉鮮白米(圓二)1.5K       272        189     51408
# 2  一匙靈Attack抗菌EX洗衣精補充-1.5Kg        69         79      5451
# 3           鴻津太國捲(蛋奶素)-370g        66         88      5808
# 4     IQ Dog 成犬乾狗糧-羊肉13.5kg        62        409     25358
#
#          CategoryName NewInvoiceDate regionName  regionID
# 0    米油沖泡_米．食用油_食用米_米     2019-12-07        中壢區       327
# 1    米油沖泡_米．食用油_食用米_米     2019-01-16        蘆竹區       325
# 2  日用百貨_家庭清潔_洗衣用品_洗衣精     2019-10-25        大溪區       325
# 3    飲料零食_精選餅乾_鹹餅乾_米果     2019-05-25        觀音區       330
# 4  生活休閒_寵物用品_狗_狗乾糧．罐頭     2019-02-20        龍潭區       338

# %% [markdown]
# ## 資料前處理

# %%
def seasonClass(x):
    if int(x.split('-')[1]) > 2 and int(x.split('-')[1]) < 6: #3,4,5月
        return 'spring'
    elif int(x.split('-')[1]) > 5 and int(x.split('-')[1]) < 9: #6,7,8月
        return 'summer'
    elif int(x.split('-')[1]) > 8 and int(x.split('-')[1]) < 12: #9,10,11月
        return 'autumn'
    else: #12,1,2月
        return 'winter'
# 新增季節欄位，根據月份來劃分
df['season'] = df['NewInvoiceDate'].apply(seasonClass)
df.head()
# Out:
#    CustomerID  InvoiceNo InvoiceDate InvoiceTime StockCode  \
# 0       16446     581483  2011-12-09    09:15:00     23843
# 1       12346     541431  2011-01-18    10:01:00     23166
# 2       12901     573008  2011-10-27    12:26:00     84077
# 3       13135     554868  2011-05-27    10:52:00     22197
# 4       18087     544612  2011-02-22    10:43:00     22053
#
#                 ProductName  Quantity  UnitPrice  Subtotal  \
# 0          中興米外銷日本之米(圓ㄧ)3Kg       285        169     48165
# 1   樂米穀場花東自然農耕特哉鮮白米(圓二)1.5K       272        189     51408
# 2  一匙靈Attack抗菌EX洗衣精補充-1.5Kg        69         79      5451
# 3           鴻津太國捲(蛋奶素)-370g        66         88      5808
# 4     IQ Dog 成犬乾狗糧-羊肉13.5kg        62        409     25358
#
#          CategoryName NewInvoiceDate regionName  regionID  season
# 0    米油沖泡_米．食用油_食用米_米     2019-12-07        中壢區       327  winter
# 1    米油沖泡_米．食用油_食用米_米     2019-01-16        蘆竹區       325  winter
# 2  日用百貨_家庭清潔_洗衣用品_洗衣精     2019-10-25        大溪區       325  autumn
# 3    飲料零食_精選餅乾_鹹餅乾_米果     2019-05-25        觀音區       330  spring
# 4  生活休閒_寵物用品_狗_狗乾糧．罐頭     2019-02-20        龍潭區       338  winter

# %%
df_season = df.groupby('season').agg({'Quantity': lambda x: x.sum()})
df_season
# Out:
#         Quantity
# season
# autumn    461841
# spring    238769
# summer    265445
# winter    260575

# %%
df_spring = df[df['season'] == 'spring']
df_summer = df[df['season'] == 'summer']
df_autumn = df[df['season'] == 'autumn']
df_winter = df[df['season'] == 'winter']
df_winter
# Out:
#         CustomerID  InvoiceNo InvoiceDate InvoiceTime StockCode  \
# 0            16446     581483  2011-12-09    09:15:00     23843
# 1            12346     541431  2011-01-18    10:01:00     23166
# 4            18087     544612  2011-02-22    10:43:00     22053
# 6            15749     540815  2011-01-11    12:55:00     21108
# 12           16333     543057  2011-02-03    10:50:00     84077
# ...            ...        ...         ...         ...       ...
# 527798       12748     581580  2011-12-09    12:20:00     22721
# 527799       12748     581580  2011-12-09    12:20:00     21351
# 527800       12748     581580  2011-12-09    12:20:00     22698
# 527801       12748     581580  2011-12-09    12:20:00     22567
# 527802       12748     581580  2011-12-09    12:20:00     37500
#
#                           ProductName  Quantity  UnitPrice  Subtotal  \
# 0                    中興米外銷日本之米(圓ㄧ)3Kg       285        169     48165
# 1             樂米穀場花東自然農耕特哉鮮白米(圓二)1.5K       272        189     51408
# 4               IQ Dog 成犬乾狗糧-羊肉13.5kg        62        409     25358
# 6                    泡舒洗潔精補充包-檸檬-800g        56         59      3304
# 12           一匙靈Attack抗菌EX洗衣精補充-1.5Kg        51         79      4029
# ...                               ...       ...        ...       ...
# 527798                    【寵物用品】富士碗-中         1         69        69
# 527799  HERAN禾聯 65吋 UHD顯示器 HD-65WDF41         1      35700     35700
# 527800                       朵蔓頭皮淨化噴霧         1        399       399
# 527801               雀巢金牌咖啡罐裝深焙風味120g         1        253       253
# 527802                爭鮮黃金甜玉米粒-340gx3         1        139       139
#
#                      CategoryName NewInvoiceDate regionName  regionID  season
# 0                米油沖泡_米．食用油_食用米_米     2019-12-07        中壢區       327  winter
# 1                米油沖泡_米．食用油_食用米_米     2019-01-16        蘆竹區       325  winter
# 4              生活休閒_寵物用品_狗_狗乾糧．罐頭     2019-02-20        龍潭區       338  winter
# 6              日用百貨_家庭清潔_廚房清潔_洗碗精     2019-01-09        觀音區       326  winter
# 12             日用百貨_家庭清潔_洗衣用品_洗衣精     2019-02-01        龜山區       336  winter
# ...                           ...            ...        ...       ...     ...
# 527798            生活休閒_寵物用品_狗_餵食器     2019-12-07        楊梅區       336  winter
# 527799  大小家電_電視．冰箱．洗衣機_電視_UHD液晶電視     2019-12-07        楊梅區       336  winter
# 527800         美妝護理_個人清潔_洗髮保養_護髮乳     2019-12-07        楊梅區       336  winter
# 527801         米油沖泡_咖啡．茶包_咖啡_即溶咖啡     2019-12-07        楊梅區       336  winter
# 527802    米油沖泡_調味品．罐頭．湯品_玉米罐頭_玉米粒     2019-12-07        楊梅區       336  winter
#
# [118959 rows x 14 columns]

# %%
df_spring_buy_rate = df_spring.groupby('StockCode').agg({'Quantity': lambda x: (x.sum())/df_season.loc['autumn']['Quantity']})
df_summer_buy_rate = df_summer.groupby('StockCode').agg({'Quantity': lambda x: (x.sum())/df_season.loc['autumn']['Quantity']})
df_autumn_buy_rate = df_autumn.groupby('StockCode').agg({'Quantity': lambda x: (x.sum())/df_season.loc['autumn']['Quantity']})
df_winter_buy_rate = df_winter.groupby('StockCode').agg({'Quantity': lambda x: (x.sum())/df_season.loc['autumn']['Quantity']})

# %%
df_spr = pd.merge(df_spring,df_spring_buy_rate,on='StockCode')
df_sum = pd.merge(df_summer,df_summer_buy_rate,on='StockCode')
df_aut = pd.merge(df_autumn,df_autumn_buy_rate,on='StockCode')
df_win = pd.merge(df_winter,df_winter_buy_rate,on='StockCode')

# %%
df1 = pd.concat([df_spr,df_sum,df_aut,df_win])
df1.rename(columns={'Quantity_x': 'Quantity', 'Quantity_y': 'Buy_index'}, inplace=True)

# %%
df1.head()
# Out:
#         CustomerID  InvoiceNo InvoiceDate InvoiceTime StockCode  \
# 0            13135     554868  2011-05-27    10:52:00     22197
# 1              477     548203  2011-03-29    16:40:00     22197
# 2            12931     550122  2011-04-14    12:39:00     22197
# 3            17949     546319  2011-03-11    09:23:00     22197
# 4            12931     553928  2011-05-20    10:02:00     22197
# ...            ...        ...         ...         ...       ...
# 118954       12748     581449  2011-12-08    17:37:00     23462
# 118955        1425     581492  2011-12-09    10:03:00     23635
# 118956        1425     581492  2011-12-09    10:03:00     23644
# 118957       14446     581538  2011-12-09    11:34:00     23033
# 118958       14446     581538  2011-12-09    11:34:00     23537
#
#                    ProductName  Quantity  UnitPrice  Subtotal  \
# 0              鴻津太國捲(蛋奶素)-370g        66         88      5808
# 1              鴻津太國捲(蛋奶素)-370g        25         88      2200
# 2              鴻津太國捲(蛋奶素)-370g        24         88      2112
# 3              鴻津太國捲(蛋奶素)-370g        22         88      1936
# 4              鴻津太國捲(蛋奶素)-370g        20         88      1760
# ...                        ...       ...        ...       ...
# 118954                 崇德發水蜜桃醋         1        199       199
# 118955  小不叮驅蚊噴霧 120ml-升級版 嬰幼兒用         1        340       340
# 118956            百研/柔軟海綿菜瓜布2入         1         69        69
# 118957        PA-112B美式四芯雙接頭5M         1         79        79
# 118958            成功可撕式按摩板擦(小)         1         32        32
#
#                       CategoryName NewInvoiceDate regionName  regionID  \
# 0                 飲料零食_精選餅乾_鹹餅乾_米果     2019-05-25        觀音區       330
# 1                 飲料零食_精選餅乾_鹹餅乾_米果     2019-03-27        龜山區       324
# 2                 飲料零食_精選餅乾_鹹餅乾_米果     2019-04-12        大溪區       330
# 3                 飲料零食_精選餅乾_鹹餅乾_米果     2019-03-09        楊梅區       325
# 4                 飲料零食_精選餅乾_鹹餅乾_米果     2019-05-18        大溪區       330
# ...                            ...            ...        ...       ...
# 118954  飲料零食_果汁．飲料．養生_濃縮飲料．水果醋_濃縮醋     2019-12-06        楊梅區       336
# 118955        母嬰保健_育嬰用品_嬰幼兒用品_防護用品     2019-12-07        大園區       337
# 118956       日用百貨_家庭清潔_清潔工具_衛浴清潔工具     2019-12-07        大園區       337
# 118957     3C_手機．通訊．週邊_電話．傳真機_電話配件     2019-12-07        新屋區       327
# 118958  生活休閒_文具．玩具．圖書_文具．辦公用品_辦公用具     2019-12-07        新屋區       327
#
#         season  Buy_index
# 0       spring   0.002312
# 1       spring   0.002312
# 2       spring   0.002312
# 3       spring   0.002312
# 4       spring   0.002312
# ...        ...        ...
# 118954  winter   0.000002
# 118955  winter   0.000002
# 118956  winter   0.000002
# 118957  winter   0.000002
# 118958  winter   0.000002
#
# [527803 rows x 15 columns]

# %%
quantiles = df1.quantile(q=[0.2,0.4,0.6,0.8])
quantiles
# Out:
#      CustomerID  InvoiceNo  Quantity  UnitPrice  Subtotal  regionID  Buy_index
# 0.2      1277.0   545545.0       1.0       69.0     108.0     325.0   0.000158
# 0.4     13571.0   555924.0       1.0      109.0     190.0     328.0   0.000338
# 0.6     15007.4   565461.0       2.0      166.0     329.0     333.0   0.000608
# 0.8     16729.0   574040.0       3.0      279.0     650.0     336.0   0.001182

# %%
quantiles = quantiles.to_dict()
quantiles
# Out:
# {'CustomerID': {0.2: 1277.0,
#   0.4: 13571.0,
#   0.6: 15007.400000000023,
#   0.8: 16729.0},
#  'InvoiceNo': {0.2: 545545.0, 0.4: 555924.0, 0.6: 565461.0, 0.8: 574040.0},
#  'Quantity': {0.2: 1.0, 0.4: 1.0, 0.6: 2.0, 0.8: 3.0},
#  'UnitPrice': {0.2: 69.0, 0.4: 109.0, 0.6: 166.0, 0.8: 279.0},
#  'Subtotal': {0.2: 108.0, 0.4: 190.0, 0.6: 329.0, 0.8: 650.0},
#  'regionID': {0.2: 325.0, 0.4: 328.0, 0.6: 333.0, 0.8: 336.0},
#  'Buy_index': {0.2: 0.00015806305633324022,
#   0.4: 0.0003377785861367873,
#   0.6: 0.0006084345045156233,
#   0.8: 0.0011822250514787556}}

# %%
def quantity_class(x,k,d):
    if x < 2:
        return 2
    elif x < 3:
        return 3
    elif x < 4:
        return 4
    else :
        return 5
def price_class(x,k,d):
    if x < d[k][0.2]:
        return 1
    elif x < d[k][0.4]:
        return 2
    elif x < d[k][0.6]:
        return 3
    elif x < d[k][0.8]:
        return 4
    else:
        return 5
def buy_index_class(x,k,d):
    if x < d[k][0.2]:
        return 1
    elif x < d[k][0.4]:
        return 2
    elif x < d[k][0.6]:
        return 3
    elif x < d[k][0.8]:
        return 4
    else:
        return 5
df1['quantity_Quartile'] = df1['Quantity'].apply(quantity_class, args=('Quantity',quantiles,))
df1['price_Quartile'] = df1['UnitPrice'].apply(price_class, args=('UnitPrice',quantiles,))
df1['buy_index_Quartile'] = df1['Buy_index'].apply(buy_index_class, args=('Buy_index',quantiles,))
df1 = df1.drop_duplicates(subset=['CustomerID','StockCode','ProductName']).sort_values(by=['CustomerID']).reset_index(drop=True)
df1['rating'] = df1['quantity_Quartile']*0.1 + df1['price_Quartile']*0.4 + df1['buy_index_Quartile']*0.5

df1.head()
# Out:
#    CustomerID  InvoiceNo InvoiceDate InvoiceTime StockCode  \
# 0           1     536544  2010-12-01    14:32:00     22664
# 1           1     536544  2010-12-01    14:32:00     22294
# 2           1     536544  2010-12-01    14:32:00     21385
# 3           1     536544  2010-12-01    14:32:00     21107
# 4           1     536544  2010-12-01    14:32:00     22379
#
#            ProductName  Quantity  UnitPrice  Subtotal  \
# 0           龍口埔里水粉400g         2         44        88
# 1  康乃馨夜用特長超薄蝶型(14片x4包)         2        176       352
# 2       家樂福哥斯大黎加濾泡式咖啡粉         1         99        99
# 3                 木柄菜匙         1         35        35
# 4          美琪天然T3抗菌洗手乳         1        101       101
#
#                    CategoryName NewInvoiceDate regionName  regionID  season  \
# 0           米油沖泡_泡麵．麵條_米粉．麵條_粉絲     2018-11-29        桃園區       326  autumn
# 1              美妝護理_女性衛生_衛生棉_夜用     2018-11-29        桃園區       326  autumn
# 2         米油沖泡_咖啡．茶包_咖啡_咖啡粉/咖啡豆     2018-11-29        桃園區       326  autumn
# 3    生活休閒_日用百貨_餐具/鍋具/廚房配件_砧板、鏟勺     2018-11-29        桃園區       326  autumn
# 4  美妝護理_個人清潔_沐浴用品_進口香皂．抗菌香皂．潔手乳     2018-11-29        桃園區       326  autumn
#
#    Buy_index  quantity_Quartile  price_Quartile  buy_index_Quartile  rating
# 0   0.000169                  3               1                   2     1.7
# 1   0.000747                  3               4                   4     3.9
# 2   0.000372                  2               2                   3     2.5
# 3   0.000214                  2               1                   2     1.6
# 4   0.001009                  2               2                   4     3.0

# %%
# 建立商品ID對應商品名稱的Dataframe
df2 = df1.drop(columns=['InvoiceNo','InvoiceDate','InvoiceTime','Quantity','UnitPrice','Subtotal','CategoryName','NewInvoiceDate','regionName','regionID','season','Buy_index'])
product_name = df2.drop_duplicates(subset=['StockCode','ProductName']).drop(columns=['CustomerID','quantity_Quartile','price_Quartile','buy_index_Quartile','rating']).reset_index(drop=True)
product_name.head()

# %%
#對個人所有評分做平均
Mean = df2.groupby(by="CustomerID",as_index=False)['rating'].mean()
Mean.head()
# Out:
#    CustomerID    rating
# 0           1  2.753257
# 1           2  2.800000
# 2           3  2.000000
# 3           4  1.300000
# 4           5  2.705433

# %%
#將平均評分合併，rating欄位名稱一樣，pandas自動變成rating_x, rating_y
Rating_avg = pd.merge(df2,Mean,on='CustomerID')
Rating_avg.head()
# Out:
#    CustomerID StockCode          ProductName  quantity_Quartile  \
# 0           1     22664           龍口埔里水粉400g                  3
# 1           1     22294  康乃馨夜用特長超薄蝶型(14片x4包)                  3
# 2           1     21385       家樂福哥斯大黎加濾泡式咖啡粉                  2
# 3           1     21107                 木柄菜匙                  2
# 4           1     22379          美琪天然T3抗菌洗手乳                  2
#
#    price_Quartile  buy_index_Quartile  rating_x  rating_y
# 0               1                   2       1.7  2.753257
# 1               4                   4       3.9  2.753257
# 2               2                   3       2.5  2.753257
# 3               1                   2       1.6  2.753257
# 4               2                   4       3.0  2.753257

# %%
#normalized rating, 因為每個人的評判'嚴格度'不一樣', ex: '阿嶽真的很嚴格', '他什麼都說好吃'
#新增欄位，值為個別評分 - 平均評分
Rating_avg['adg_rating']=Rating_avg['rating_x']-Rating_avg['rating_y']
Rating_avg.head()
# Out:
#    CustomerID StockCode          ProductName  quantity_Quartile  \
# 0           1     22664           龍口埔里水粉400g                  3
# 1           1     22294  康乃馨夜用特長超薄蝶型(14片x4包)                  3
# 2           1     21385       家樂福哥斯大黎加濾泡式咖啡粉                  2
# 3           1     21107                 木柄菜匙                  2
# 4           1     22379          美琪天然T3抗菌洗手乳                  2
#
#    price_Quartile  buy_index_Quartile  rating_x  rating_y  adg_rating
# 0               1                   2       1.7  2.753257   -1.053257
# 1               4                   4       3.9  2.753257    1.146743
# 2               2                   3       2.5  2.753257   -0.253257
# 3               1                   2       1.6  2.753257   -1.153257
# 4               2                   4       3.0  2.753257    0.246743

# %%
#做出userId-itemID的pivot table, 因為每個人可能只買過幾樣商品, 所以是一個很大的稀疏矩陣
final=pd.pivot_table(Rating_avg,values='adg_rating',index='CustomerID',columns='StockCode')
final
# Out:
# StockCode   10002  10080  10120  10123C  10124A  10124G  10125  10133  \
# CustomerID
# 1             NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN
# 2             NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN
# 3             NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN
# 4             NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN
# 5             NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN
# ...           ...    ...    ...     ...     ...     ...    ...    ...
# 18280         NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN
# 18281         NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN
# 18282         NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN
# 18283         NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN
# 18287         NaN    NaN    NaN     NaN     NaN     NaN    NaN    NaN
#
# StockCode      10135     11001  ...  DCGS0069  DCGS0070  DCGS0076  DCGSSBOY  \
# CustomerID                      ...
# 1                NaN  0.146743  ...       NaN       NaN       NaN       NaN
# 2                NaN       NaN  ...       NaN       NaN       NaN       NaN
# 3                NaN       NaN  ...       NaN       NaN       NaN       NaN
# 4                NaN       NaN  ...       NaN       NaN       NaN       NaN
# 5           0.494567       NaN  ...       NaN       NaN       NaN       NaN
# ...              ...       ...  ...       ...       ...       ...       ...
# 18280            NaN       NaN  ...       NaN       NaN       NaN       NaN
# 18281            NaN       NaN  ...       NaN       NaN       NaN       NaN
# 18282            NaN       NaN  ...       NaN       NaN       NaN       NaN
# 18283            NaN       NaN  ...       NaN       NaN       NaN       NaN
# 18287            NaN       NaN  ...       NaN       NaN       NaN       NaN
#
# StockCode   DCGSSGIRL  gift_0001_10  gift_0001_20  gift_0001_30  gift_0001_40  \
# CustomerID
# 1                 NaN           NaN           NaN           NaN           NaN
# 2                 NaN           NaN           NaN           NaN           NaN
# 3                 NaN           NaN           NaN           NaN           NaN
# 4                 NaN           NaN           NaN           NaN           NaN
# 5                 NaN           NaN           NaN           NaN           NaN
# ...               ...           ...           ...           ...           ...
# 18280             NaN           NaN           NaN           NaN           NaN
# 18281             NaN           NaN           NaN           NaN           NaN
# 18282             NaN           NaN           NaN           NaN           NaN
# 18283             NaN           NaN           NaN           NaN           NaN
# 18287             NaN           NaN           NaN           NaN           NaN
#
# StockCode   gift_0001_50
# CustomerID
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# 5                    NaN
# ...                  ...
# 18280                NaN
# 18281                NaN
# 18282                NaN
# 18283                NaN
# 18287                NaN
#
# [5708 rows x 3914 columns]

# %%
#填空值
#方法一：以userId列的標準化評分的平均填入
#方法二：以商品Id欄的標準化評分的平均填入 <---我們選這個
final_item = final.fillna(final.mean(axis=0))
final_item
# Out:
# StockCode      10002     10080     10120   10123C   10124A   10124G     10125  \
# CustomerID
# 1          -0.858445 -0.942859 -0.489305 -0.12973 -0.18104 -1.80607 -0.967031
# 2          -0.858445 -0.942859 -0.489305 -0.12973 -0.18104 -1.80607 -0.967031
# 3          -0.858445 -0.942859 -0.489305 -0.12973 -0.18104 -1.80607 -0.967031
# 4          -0.858445 -0.942859 -0.489305 -0.12973 -0.18104 -1.80607 -0.967031
# 5          -0.858445 -0.942859 -0.489305 -0.12973 -0.18104 -1.80607 -0.967031
# ...              ...       ...       ...      ...      ...      ...       ...
# 18280      -0.858445 -0.942859 -0.489305 -0.12973 -0.18104 -1.80607 -0.967031
# 18281      -0.858445 -0.942859 -0.489305 -0.12973 -0.18104 -1.80607 -0.967031
# 18282      -0.858445 -0.942859 -0.489305 -0.12973 -0.18104 -1.80607 -0.967031
# 18283      -0.858445 -0.942859 -0.489305 -0.12973 -0.18104 -1.80607 -0.967031
# 18287      -0.858445 -0.942859 -0.489305 -0.12973 -0.18104 -1.80607 -0.967031
#
# StockCode      10133     10135     11001  ...  DCGS0069  DCGS0070  DCGS0076  \
# CustomerID                                ...
# 1           0.026938  0.636627  0.146743  ... -0.366102  0.036765  0.082684
# 2           0.026938  0.636627  0.193614  ... -0.366102  0.036765  0.082684
# 3           0.026938  0.636627  0.193614  ... -0.366102  0.036765  0.082684
# 4           0.026938  0.636627  0.193614  ... -0.366102  0.036765  0.082684
# 5           0.026938  0.494567  0.193614  ... -0.366102  0.036765  0.082684
# ...              ...       ...       ...  ...       ...       ...       ...
# 18280       0.026938  0.636627  0.193614  ... -0.366102  0.036765  0.082684
# 18281       0.026938  0.636627  0.193614  ... -0.366102  0.036765  0.082684
# 18282       0.026938  0.636627  0.193614  ... -0.366102  0.036765  0.082684
# 18283       0.026938  0.636627  0.193614  ... -0.366102  0.036765  0.082684
# 18287       0.026938  0.636627  0.193614  ... -0.366102  0.036765  0.082684
#
# StockCode   DCGSSBOY  DCGSSGIRL  gift_0001_10  gift_0001_20  gift_0001_30  \
# CustomerID
# 1           0.025156  -1.180128     -1.161536     -0.418427     -1.588743
# 2           0.025156  -1.180128     -1.161536     -0.418427     -1.588743
# 3           0.025156  -1.180128     -1.161536     -0.418427     -1.588743
# 4           0.025156  -1.180128     -1.161536     -0.418427     -1.588743
# 5           0.025156  -1.180128     -1.161536     -0.418427     -1.588743
# ...              ...        ...           ...           ...           ...
# 18280       0.025156  -1.180128     -1.161536     -0.418427     -1.588743
# 18281       0.025156  -1.180128     -1.161536     -0.418427     -1.588743
# 18282       0.025156  -1.180128     -1.161536     -0.418427     -1.588743
# 18283       0.025156  -1.180128     -1.161536     -0.418427     -1.588743
# 18287       0.025156  -1.180128     -1.161536     -0.418427     -1.588743
#
# StockCode   gift_0001_40  gift_0001_50
# CustomerID
# 1               0.015588     -1.518989
# 2               0.015588     -1.518989
# 3               0.015588     -1.518989
# 4               0.015588     -1.518989
# 5               0.015588     -1.518989
# ...                  ...           ...
# 18280           0.015588     -1.518989
# 18281           0.015588     -1.518989
# 18282           0.015588     -1.518989
# 18283           0.015588     -1.518989
# 18287           0.015588     -1.518989
#
# [5708 rows x 3914 columns]

# %% [markdown]
# # 計算相似度

# %%
# 用cosine_similarity計算每個USER的相似度
cosine = cosine_similarity(final_item)
print(cosine.shape)
cosine
# Out:
# (5708, 5708)
# array([[1.        , 0.98782338, 0.98770869, ..., 0.987053  , 0.97816604,
#         0.98714561],
#        [0.98782338, 1.        , 0.99988178, ..., 0.99943052, 0.99313719,
#         0.99886576],
#        [0.98770869, 0.99988178, 1.        , ..., 0.99931256, 0.993019  ,
#         0.99874817],
#        ...,
#        [0.987053  , 0.99943052, 0.99931256, ..., 1.        , 0.99257244,
#         0.99829686],
#        [0.97816604, 0.99313719, 0.993019  , ..., 0.99257244, 1.        ,
#         0.99265678],
#        [0.98714561, 0.99886576, 0.99874817, ..., 0.99829686, 0.99265678,
#         1.        ]])

# %%
#把對角線的值換成 0
np.fill_diagonal(cosine, 0 )
cosine
# Out:
# array([[0.        , 0.98782338, 0.98770869, ..., 0.987053  , 0.97816604,
#         0.98714561],
#        [0.98782338, 0.        , 0.99988178, ..., 0.99943052, 0.99313719,
#         0.99886576],
#        [0.98770869, 0.99988178, 0.        , ..., 0.99931256, 0.993019  ,
#         0.99874817],
#        ...,
#        [0.987053  , 0.99943052, 0.99931256, ..., 0.        , 0.99257244,
#         0.99829686],
#        [0.97816604, 0.99313719, 0.993019  , ..., 0.99257244, 0.        ,
#         0.99265678],
#        [0.98714561, 0.99886576, 0.99874817, ..., 0.99829686, 0.99265678,
#         0.        ]])

# %%
#把cosine array變成data frame, index是CustomerID
similarity_with_user = pd.DataFrame(cosine, index=final_item.index)

#把columns換成userId
similarity_with_user.columns = final_item.index
similarity_with_user
# Out:
#                 0         1         2         3         4         5     \
# CustomerID
# 1           0.000000  0.987823  0.987709  0.987093  0.987916  0.987837
# 2           0.987823  0.000000  0.999882  0.999290  0.984584  0.999885
# 3           0.987709  0.999882  0.000000  0.999172  0.984468  0.999800
# 4           0.987093  0.999290  0.999172  0.000000  0.983889  0.999175
# 5           0.987916  0.984584  0.984468  0.983889  0.000000  0.984613
# ...              ...       ...       ...       ...       ...       ...
# 18280       0.987691  0.999872  0.999754  0.999163  0.984015  0.999757
# 18281       0.987764  0.999939  0.999820  0.999229  0.984509  0.999823
# 18282       0.987053  0.999431  0.999313  0.998722  0.983798  0.999315
# 18283       0.978166  0.993137  0.993019  0.992427  0.974805  0.992933
# 18287       0.987146  0.998866  0.998748  0.998159  0.984108  0.998804
#
#                 6         7         8         9     ...      5698      5699  \
# CustomerID                                          ...
# 1           0.987517  0.987873  0.987831  0.987902  ...  0.987821  0.987685
# 2           0.999786  0.999584  0.999588  0.999923  ...  0.999998  0.999780
# 3           0.999668  0.999466  0.999470  0.999805  ...  0.999880  0.999662
# 4           0.999076  0.998875  0.998879  0.999213  ...  0.999288  0.999070
# 5           0.984237  0.984913  0.984813  0.984738  ...  0.984586  0.984443
# ...              ...       ...       ...       ...  ...       ...       ...
# 18280       0.999659  0.999457  0.999461  0.999795  ...  0.999870  0.999652
# 18281       0.999724  0.999522  0.999526  0.999861  ...  0.999936  0.999718
# 18282       0.999217  0.999015  0.999019  0.999354  ...  0.999428  0.999005
# 18283       0.993003  0.992466  0.992506  0.993060  ...  0.993135  0.992934
# 18287       0.998653  0.998505  0.998454  0.998854  ...  0.998864  0.998646
#
#                 5700      5701      5702      5703      5704      5705  \
# CustomerID
# 1           0.987709  0.987773  0.987054  0.987691  0.987764  0.987053
# 2           0.999919  0.999958  0.999639  0.999872  0.999939  0.999431
# 3           0.999801  0.999840  0.999521  0.999754  0.999820  0.999313
# 4           0.999210  0.999249  0.998929  0.999163  0.999229  0.998722
# 5           0.984468  0.984517  0.983929  0.984015  0.984509  0.983798
# ...              ...       ...       ...       ...       ...       ...
# 18280       0.999792  0.999831  0.999515  0.000000  0.999812  0.999303
# 18281       0.999857  0.999897  0.999577  0.999812  0.000000  0.999369
# 18282       0.999350  0.999389  0.999070  0.999303  0.999369  0.000000
# 18283       0.993054  0.993111  0.992776  0.993012  0.993055  0.992572
# 18287       0.998787  0.998824  0.998456  0.998738  0.998804  0.998297
#
#                 5706      5707
# CustomerID
# 1           0.978166  0.987146
# 2           0.993137  0.998866
# 3           0.993019  0.998748
# 4           0.992427  0.998159
# 5           0.974805  0.984108
# ...              ...       ...
# 18280       0.993012  0.998738
# 18281       0.993055  0.998804
# 18282       0.992572  0.998297
# 18283       0.000000  0.992657
# 18287       0.992657  0.000000
#
# [5708 rows x 5708 columns]

# %%
# 建立商品ID與商品名的 dataframe
items = df2.drop_duplicates(subset=['StockCode']).drop(columns=['CustomerID','quantity_Quartile','price_Quartile','buy_index_Quartile','rating']).sort_values(by=['StockCode']).reset_index(drop=True)
items.head()
# Out:
#   StockCode     ProductName
# 0     10002           桂冠大沙拉
# 1     10080        水手牌鬆餅預拌粉
# 2     10120         老奶奶檸檬蛋糕
# 3    10123C  收藏家電子防潮箱 CF-87
# 4    10124A  棉花共和國中空快乾浴巾-藍色

# %%
# 找出兩個使用者購買的相同商品
def get_user_similar_retailer( user1, user2 ):
    common_items = Rating_avg[Rating_avg.CustomerID == user1].merge(
    Rating_avg[Rating_avg.CustomerID == user2],
    on = "StockCode",
    how = "inner" )
    return common_items.merge( items, on = 'StockCode' )

#檢查是否合理
a = get_user_similar_retailer(1,1000)
a = a.loc[ : , ['rating_x_x','rating_x_y','ProductName']] # a.loc[取全部,['欄位1','欄位2','欄位3']] --> 取出欄位1,2,3的所有值
a.head()
# Out:
#    rating_x_x  rating_x_y         ProductName
# 0         1.6         1.1                木柄菜匙
# 1         3.0         3.0         美琪天然T3抗菌洗手乳
# 2         3.8         3.4  歐邁福麵包餅乾香蒜奶油口味-300g
# 3         3.5         3.5     OP生物分解抗菌立體密封袋 L
# 4         3.2         2.7    3M新防蹣水洗枕幼兒型(附枕套)

# %%
#order = np.argsort(df.values, axis=1)[:, :n] 
#按做排序列，並返回該值排序後的index
#每一列變Series做降冪排列，取出前n個, index換成Top1~Topn
def find_n_neighbours(df,n):
    df = df.apply(lambda x: pd.Series(x.sort_values(ascending=False)
           .iloc[:n].index, 
          index=['top{}'.format(i) for i in range(1, n+1)]), axis=1)
    return df
# top 30 neighbours for each user
sim_user_30 = find_n_neighbours(similarity_with_user,30)
sim_user_30.head()
# Out:
#              top1   top2   top3   top4   top5   top6   top7   top8   top9  \
# CustomerID
# 1           16274  17908  17968  17976  12433  16352  14142  12842  14511
# 2             464     34     15  17443    599    621  18268   1079  18087
# 3             107  18068    770    464     34     15  17443    599  18268
# 4             464     15     34  17443    599  18268    621   1079  18087
# 5               1  17968  13311      8   1117  12638  17908  16352  13532
#
#             top10  ...  top21  top22  top23  top24  top25  top26  top27  \
# CustomerID         ...
# 1           16478  ...  17603  14494  15458  16753  13483  15626  12686
# 2             520  ...    862     54  16257  17788    933    961   1014
# 3             621  ...  15100    947    664  17408    862     54  16257
# 4             520  ...  17408    862     54  16257  17788    933    961
# 5           14142  ...  16274  12371  16017  13067  14047  14511  15679
#
#             top28  top29  top30
# CustomerID
# 1           14047  16017  13108
# 2           13967    165    738
# 3           17788    933    961
# 4            1014  13967    165
# 5           14386  14494  13732
#
# [5 rows x 30 columns]

# %%
# 計算使用者對物品的喜好分數
def User_item_score(user,item):
    a = sim_user_30[sim_user_30.index==user].values #抓出top30表格，index==userId的列，把30個值變成一個array
    b = a.squeeze().tolist() #array降一維度，並變成list ex:[0.2,0.4,,,,,0.6]
    c = final_item.loc[:,item]
    d = c[c.index.isin(b)]
    f = d[d.notnull()]
    avg_user = Mean.loc[Mean['CustomerID'] == user,'rating'].values[0]
    index = f.index.values.squeeze().tolist()
    corr = similarity_with_user.loc[user,index]
    fin = pd.concat([f, corr], axis=1)
    fin.columns = ['adg_score','correlation']
    fin['score']=fin.apply(lambda x:x['adg_score'] * x['correlation'],axis=1)
    nume = fin['score'].sum()
    deno = fin['correlation'].sum()
    final_score = avg_user + (nume/deno)
    return final_score

User_item_score(1,'10124A')
# Out:
# 2.5722170746502844

# %%
#使用者買過的商品ID放在同一列
Rating_avg = Rating_avg.astype({"StockCode": str}) #itemId 的值變成str
Item_user = Rating_avg.groupby(by = 'CustomerID')['StockCode'].apply(lambda x:','.join(x))
Item_user
# Out:
# CustomerID
# 1        22664,22294,21385,21107,22379,21787,22633,1701...
# 2                                              22716,20697
# 3                                                    22802
# 4                                              21372,21369
# 5        20668,22748,22352,22867,20696,85064,84755,2128...
#                                ...
# 18280    22467,22499,22084,22611,22358,22180,22495,8248...
# 18281            22716,23008,23007,22028,22037,22467,23209
# 18282    22699,22818,21270,21108,23174,22423,22424,2110...
# 18283    21982,22139,23380,85150,20727,22735,22030,2202...
# 18287    84507C,22419,23445,21556,23274,22644,22865,226...
# Name: StockCode, Length: 5708, dtype: object

# %%
# 輸入使用者跟推薦商品數量 --> 推薦List
def user_based_recommend(user,n):
    Items_bought_by_user = final.columns[final[final.index==user].notna().any()].tolist()
    a = sim_user_30[sim_user_30.index==user].values
    b = a.squeeze().tolist()
    d = Item_user[Item_user.index.isin(b)]
    l = ','.join(d.values)
    Items_bought_by_similar_users = l.split(',')
    Items_under_consideration = list(set(Items_bought_by_similar_users)-set(list(map(str, Items_bought_by_user))))
    #Items_under_consideration = list(map(int, Items_under_consideration))
    score = []
    for item in Items_under_consideration:
        c = final_item.loc[:,item]
        d = c[c.index.isin(b)]
        f = d[d.notnull()]
        avg_user = Mean.loc[Mean['CustomerID'] == user,'rating'].values[0]
        index = f.index.values.squeeze().tolist()
        corr = similarity_with_user.loc[user,index]
        fin = pd.concat([f, corr], axis=1)
        fin.columns = ['adg_score','correlation']
        fin['score']=fin.apply(lambda x:x['adg_score'] * x['correlation'],axis=1)
        nume = fin['score'].sum()
        deno = fin['correlation'].sum()
        final_score = avg_user + (nume/deno)
        score.append(final_score)
    data = pd.DataFrame({'StockCode':Items_under_consideration,'score':score})
    top_n_recommendation = data.sort_values(by='score',ascending=False).head(n)
    Item_Name = top_n_recommendation.merge(items, how='inner', on='StockCode')
    Item_Names = Item_Name.ProductName.values.tolist()
    return Item_Names

# %%
# 結果
user_based_recommend(1000,10)
# Out:
# ['UCC炭燒濾掛式咖啡-8gx24',
#  '維他露大蘋果蘇打-250mlx24',
#  '皇家榖堡皇家台東米(圓ㄧ)3Kg',
#  '五月花蓬厚柔三層抽取衛生紙-110PCx72',
#  '家樂福冷凍黑豬五花火鍋片(每盒約250克)',
#  '西莎野菜牛肉100g6入/組',
#  '舒味思葡萄柚口味汽水-330mlx24',
#  '家樂福超值抗菌濃縮洗衣精',
#  'YS加強六星潔牙棒棒L桶裝',
#  '南亞保鮮膜真省包 3支/組']
